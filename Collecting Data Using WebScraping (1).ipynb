# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# *   Download a webpage using requests module
# *   Scrape all links from a web page
# *   Scrape all image urls from a web page
# *   Scrape data from html tables

# %% [markdown]
# ## Scrape [www.ibm.com](http://www.ibm.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01)

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the contents of the web page

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# /uk-en/sustainability?lnk=hpv18l1
# https://newsroom.ibm.com/2022-09-14-IBM-Announced-as-COP-27-Technology-Partner?lnk=hpv18l2
# https://uk.newsroom.ibm.com/?lnk=hpv18nf1
# https://www.ibm.com/uk-en/about/secure-your-business/?lnk=hpv18f1
# https://www.ibm.com/uk-en/cloud/campaign/cloud-simplicity?lnk=hpv18f2
# https://www.ibm.com/uk-en/data-fabric?lnk=hpv18f3
# https://www.ibm.com/uk-en/cloud/aiops?lnk=hpv18f4
# https://www.ibm.com/consulting/uk-en/?lnk=hpv18f5
# https://www.ibm.com/uk-en/products?lnk=hpv18fp
# https://www.ibm.com/easytools/cpds/power/uk-en?pageid=170853&lnk=hpv18fp
# https://www.ibm.com/it-infrastructure/storage/flash/offers/uk-en?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/z16?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/cloud-pak-for-watson-aiops?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/cloud-pak-for-data?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/cloud-pak-for-business-automation?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/cloud-pak-for-integration?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/cloud-pak-for-network-automation?lnk=hpv18fp
# https://www.ibm.com/uk-en/products/cloud-pak-for-security?lnk=hpv18fp
# https://www.ibm.com/uk-en/cloud?lnk=hpv18fp
# https://developer.ibm.com/depmodels/cloud/?lnk=hpv18ct16
# https://developer.ibm.com/technologies/artificial-intelligence?lnk=hpv18ct19
# https://developer.ibm.com/?lnk=hpv18ct9
# https://www.ibm.com/docs/en?lnk=hpv18ct14
# https://www.redbooks.ibm.com/?lnk=ushpv18ct10
# https://www.ibm.com/support/home/?lnk=hpv18ct11
# https://www.ibm.com/training/?lnk=hpv18ct15
# /cloud/hybrid?lnk=hpv18pt14
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /watson?lnk=ushpv18pt17
# /garage?lnk=hpv18pt13
# /blockchain?lnk=hpv18pt4
# https://www.ibm.com/thought-leadership/institute-business-value/?lnk=hpv18pt12
# /analytics?lnk=hpv18pt1
# /security?lnk=hpv18pt9
# /financing?lnk=hpv18pt3
# https://www.ibm.com/quantum-computing?lnk=hpv18pt16
# /cloud/hybrid?lnk=hpv18ct20
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /cloud/redhat?lnk=hpv18ct13
# /watson?lnk=hpv18ct3
# //1.cms.s81c.com/sites/default/files/2022-10-14/CI_Cloud%20Pak%20for%20Data_608x342.png
# //1.cms.s81c.com/sites/default/files/2022-10-14/CI_Cloud%20Pak%20for%20Business%20Automation_608x342.png
# //1.cms.s81c.com/sites/default/files/2022-10-14/CI_Cloud%20Pak%20for%20Integration_608x342.png
# //1.cms.s81c.com/sites/default/files/2022-10-14/CI_Cloud%20Pak%20for%20Network%20Automation_608x342.png
# //1.cms.s81c.com/sites/default/files/2022-10-14/CI_Cloud%20Pak%20for%20Security_608x342.png
# //1.cms.s81c.com/sites/default/files/2022-10-14/CI_IBM%20Cloud_608x342.png

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below url contains a html table with data about colors and color codes.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %%
df=pd.DataFrame(table,columns=["Language","Average Annual Salary"])
df.drop(df.index[0], inplace=True)
df.to_csv('popular-languages.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/wsuser/ipykernel_403/1395209599.py in <module>
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame(table,columns=["Language","Average Annual Salary"])
#       3 df.drop(df.index[0], inplace=True)
#       4 df.to_csv('popular-languages.csv')
#       5 df
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (2, 1), indices imply (2, 2)

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd

# %%
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
table = pd.DataFrame(columns={"Language","Average Annual Salary"})

for row in soup.find_all('tr'):
    cols = row.find_all('td')
    language = cols[1].getText() 
    salary = cols[3].getText() 
    print("{}--->{}".format(language,salary))
    table = table.append({"Language": language, "Average Annual Salary": salary}, ignore_index=True)
    table.head()
# Out:
# Language--->Average Annual Salary
# Python--->$114,383
# Java--->$101,013
# R--->$92,037
# Javascript--->$110,981
# Swift--->$130,801
# C++--->$113,865
# C#--->$88,726
# PHP--->$84,727
# SQL--->$84,793
# Go--->$94,082

# %%
df=pd.DataFrame(table,columns=["Language","Average Annual Salary"])
df.drop(df.index[0], inplace=True)
df.to_csv('popular-languages.csv')
df
# Out:
#       Language Average Annual Salary
# 1       Python              $114,383
# 2         Java              $101,013
# 3            R               $92,037
# 4   Javascript              $110,981
# 5        Swift              $130,801
# 6          C++              $113,865
# 7           C#               $88,726
# 8          PHP               $84,727
# 9          SQL               $84,793
# 10          Go               $94,082

# %%
import numpy as np
import matplotlib.pyplot as plt

df.sort_values('Language',inplace=True)

fig = plt.figure(figsize = (15,10))
 
# creating the bar plot
plt.bar(df['Language'], df['Average Annual Salary'], color ='maroon',
        width = 0.4)
 
plt.xlabel("Average Annual Salary")
plt.ylabel("Language")
plt.title("POPULAR LANGUAGES")
plt.show()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01).
